# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajikshank/ML_files/blob/main/C1_W2_Lab02_Multiple_Variable_Soln_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Optional Lab: Multiple Variable Linear Regression
#
# In this lab, you will extend the data structures and previously developed routines to support multiple features. Several routines are updated making the lab appear lengthy, but it makes minor adjustments to previous routines making it quick to review.
# # Outline
# - [&nbsp;&nbsp;1.1 Goals](#toc_15456_1.1)
# - [&nbsp;&nbsp;1.2 Tools](#toc_15456_1.2)
# - [&nbsp;&nbsp;1.3 Notation](#toc_15456_1.3)
# - [2 Problem Statement](#toc_15456_2)
# - [&nbsp;&nbsp;2.1 Matrix X containing our examples](#toc_15456_2.1)
# - [&nbsp;&nbsp;2.2 Parameter vector w, b](#toc_15456_2.2)
# - [3 Model Prediction With Multiple Variables](#toc_15456_3)
# - [&nbsp;&nbsp;3.1 Single Prediction element by element](#toc_15456_3.1)
# - [&nbsp;&nbsp;3.2 Single Prediction, vector](#toc_15456_3.2)
# - [4 Compute Cost With Multiple Variables](#toc_15456_4)
# - [5 Gradient Descent With Multiple Variables](#toc_15456_5)
# - [&nbsp;&nbsp;5.1 Compute Gradient with Multiple Variables](#toc_15456_5.1)
# - [&nbsp;&nbsp;5.2 Gradient Descent With Multiple Variables](#toc_15456_5.2)
# - [6 Congratulations](#toc_15456_6)

# %% [markdown]
# <a name="toc_15456_1.1"></a>
# ## 1.1 Goals
# - Extend our regression model  routines to support multiple features
#     - Extend data structures to support multiple features
#     - Rewrite prediction, cost and gradient routines to support multiple features
#     - Utilize NumPy `np.dot` to vectorize their implementations for speed and simplicity

# %% [markdown]
# <a name="toc_15456_1.2"></a>
# ## 1.2 Tools
# In this lab, we will make use of:
# - NumPy, a popular library for scientific computing
# - Matplotlib, a popular library for plotting data

# %%
import copy, math
import numpy as np
import matplotlib.pyplot as plt
#plt.style.use('./deeplearning.mplstyle')
np.set_printoptions(precision=2)  # reduced display precision on numpy arrays

# %% [markdown]
# <a name="toc_15456_1.3"></a>
# ## 1.3 Notation
# Here is a summary of some of the notation you will encounter, updated for multiple features.
#
# |General <img width=70/> <br />  Notation  <img width=70/> | Description<img width=350/>| Python (if applicable) |
# |: ------------|: ------------------------------------------------------------||
# | $a$ | scalar, non bold                                                      ||
# | $\mathbf{a}$ | vector, bold                                                 ||
# | $\mathbf{A}$ | matrix, bold capital                                         ||
# | **Regression** |         |    |     |
# |  $\mathbf{X}$ | training example matrix                  | `X_train` |
# |  $\mathbf{y}$  | training example  targets                | `y_train`
# |  $\mathbf{x}^{(i)}$, $y^{(i)}$ | $i_{th}$Training Example | `X[i]`, `y[i]`|
# | m | number of training examples | `m`|
# | n | number of features in each example | `n`|
# |  $\mathbf{w}$  |  parameter: weight,                       | `w`    |
# |  $b$           |  parameter: bias                                           | `b`    |
# | $f_{\mathbf{w},b}(\mathbf{x}^{(i)})$ | The result of the model evaluation at $\mathbf{x^{(i)}}$ parameterized by $\mathbf{w},b$: $f_{\mathbf{w},b}(\mathbf{x}^{(i)}) = \mathbf{w} \cdot \mathbf{x}^{(i)}+b$  | `f_wb` |

# %% [markdown]
# <a name="toc_15456_2"></a>
# # 2 Problem Statement
#
# You will use the motivating example of housing price prediction. The training dataset contains three examples with four features (size, bedrooms, floors and, age) shown in the table below.  Note that, unlike the earlier labs, size is in sqft rather than 1000 sqft. This causes an issue, which you will solve in the next lab!
#
# | Size (sqft) | Number of Bedrooms  | Number of floors | Age of  Home | Price (1000s dollars)  |
# | ----------------| ------------------- |----------------- |--------------|-------------- |
# | 2104            | 5                   | 1                | 45           | 460           |
# | 1416            | 3                   | 2                | 40           | 232           |
# | 852             | 2                   | 1                | 35           | 178           |
#
# You will build a linear regression model using these values so you can then predict the price for other houses. For example, a house with 1200 sqft, 3 bedrooms, 1 floor, 40 years old.
#
# Please run the following code cell to create your `X_train` and `y_train` variables.

# %%
X_train = np.array([[2104, 5, 1, 45], [1416, 3, 2, 40], [852, 2, 1, 35]])
y_train = np.array([460, 232, 178])


print(X_train[0,1])
X_train.T
# Out:
# 5
# array([[2104, 1416,  852],
#        [   5,    3,    2],
#        [   1,    2,    1],
#        [  45,   40,   35]])

# %% [markdown]
# <a name="toc_15456_2.1"></a>
# ## 2.1 Matrix X containing our examples
# Similar to the table above, examples are stored in a NumPy matrix `X_train`. Each row of the matrix represents one example. When you have $m$ training examples ( $m$ is three in our example), and there are $n$ features (four in our example), $\mathbf{X}$ is a matrix with dimensions ($m$, $n$) (m rows, n columns).
#
#
# $$\mathbf{X} =
# \begin{pmatrix}
#  x^{(0)}_0 & x^{(0)}_1 & \cdots & x^{(0)}_{n-1} \\
#  x^{(1)}_0 & x^{(1)}_1 & \cdots & x^{(1)}_{n-1} \\
#  \cdots \\
#  x^{(m-1)}_0 & x^{(m-1)}_1 & \cdots & x^{(m-1)}_{n-1}
# \end{pmatrix}
# $$
# notation:
# - $\mathbf{x}^{(i)}$ is vector containing example i. $\mathbf{x}^{(i)}$ $ = (x^{(i)}_0, x^{(i)}_1, \cdots,x^{(i)}_{n-1})$
# - $x^{(i)}_j$ is element j in example i. The superscript in parenthesis indicates the example number while the subscript represents an element.
#
# Display the input data.

# %%
# data is stored in numpy array/matrix
print(f"X Shape: {X_train.shape}, X Type:{type(X_train)})")
print(X_train)
print(f"y Shape: {y_train.shape}, y Type:{type(y_train)})")
print(y_train)
# Out:
# X Shape: (3, 4), X Type:<class 'numpy.ndarray'>)
# [[2104    5    1   45]
#  [1416    3    2   40]
#  [ 852    2    1   35]]
# y Shape: (3,), y Type:<class 'numpy.ndarray'>)
# [460 232 178]

# %% [markdown]
# <a name="toc_15456_2.2"></a>
# ## 2.2 Parameter vector w, b
#
# * $\mathbf{w}$ is a vector with $n$ elements.
#   - Each element contains the parameter associated with one feature.
#   - in our dataset, n is 4.
#   - notionally, we draw this as a column vector
#
# $$\mathbf{w} = \begin{pmatrix}
# w_0 \\
# w_1 \\
# \cdots\\
# w_{n-1}
# \end{pmatrix}
# $$
# * $b$ is a scalar parameter.

# %% [markdown]
# For demonstration, $\mathbf{w}$ and $b$ will be loaded with some initial selected values that are near the optimal. $\mathbf{w}$ is a 1-D NumPy vector.

# %%
b_init = 785.1811367994083
w_init = np.array([ 0.39133535, 18.75376741, -53.36032453, -26.42131618])
print(f"w_init shape: {w_init.shape}, b_init type: {type(b_init)}")
# Out:
# w_init shape: (4,), b_init type: <class 'float'>

# %% [markdown]
# <a name="toc_15456_3"></a>
# # 3 Model Prediction With Multiple Variables
# The model's prediction with multiple variables is given by the linear model:
#
# $$ f_{\mathbf{w},b}(\mathbf{x}) =  w_0x_0 + w_1x_1 +... + w_{n-1}x_{n-1} + b \tag{1}$$
# or in vector notation:
# $$ f_{\mathbf{w},b}(\mathbf{x}) = \mathbf{w} \cdot \mathbf{x} + b  \tag{2} $$
# where $\cdot$ is a vector `dot product`
#
# To demonstrate the dot product, we will implement prediction using (1) and (2).

# %% [markdown]
# <a name="toc_15456_3.1"></a>
# ## 3.1 Single Prediction element by element
# Our previous prediction multiplied one feature value by one parameter and added a bias parameter. A direct extension of our previous implementation of prediction to multiple features would be to implement (1) above using loop over each element, performing the multiply with its parameter and then adding the bias parameter at the end.

# %%
def predict_single_loop(x, w, b):
    """
    single predict using linear regression

    Args:
      x (ndarray): Shape (n,) example with multiple features
      w (ndarray): Shape (n,) model parameters
      b (scalar):  model parameter

    Returns:
      p (scalar):  prediction
    """
    n = x.shape[0]
    p = 0
    for i in range(n):
        p_i = x[i] * w[i]
        print(x[i],"   ",w[i])
        p = p + p_i
    p = p + b
    return p

# %%
# get a row from our training data
x_vec = X_train[0,:]
print(f"x_vec shape {x_vec.shape}, x_vec value: {x_vec}")

# make a prediction
f_wb = predict_single_loop(x_vec, w_init, b_init)
print(f"f_wb shape {f_wb.shape}, prediction: {f_wb}")
# Out:
# x_vec shape (4,), x_vec value: [2104    5    1   45]
# 2104     0.39133535
# 5     18.75376741
# 1     -53.36032453
# 45     -26.42131618
# f_wb shape (), prediction: 459.9999976194083

# %% [markdown]
# Note the shape of `x_vec`. It is a 1-D NumPy vector with 4 elements, (4,). The result, `f_wb` is a scalar.

# %% [markdown]
# <a name="toc_15456_3.2"></a>
# ## 3.2 Single Prediction, vector
#
# Noting that equation (1) above can be implemented using the dot product as in (2) above. We can make use of vector operations to speed up predictions.
#
# Recall from the Python/Numpy lab that NumPy `np.dot()`[[link](https://numpy.org/doc/stable/reference/generated/numpy.dot.html)] can be used to perform a vector dot product.

# %%
def predict(x, w, b):
    """
    single predict using linear regression
    Args:
      x (ndarray): Shape (n,) example with multiple features
      w (ndarray): Shape (n,) model parameters
      b (scalar):             model parameter

    Returns:
      p (scalar):  prediction
    """
    p = np.dot(x, w) + b
    return p

# %%
# get a row from our training data
x_vec = X_train[0,:]
print(f"x_vec shape {x_vec.shape}, x_vec value: {x_vec}")

# make a prediction
f_wb = predict(x_vec,w_init, b_init)
print(f"f_wb shape {f_wb.shape}, prediction: {f_wb}")
# Out:
# x_vec shape (4,), x_vec value: [2104    5    1   45]
# f_wb shape (), prediction: 459.9999976194083

# %% [markdown]
# The results and shapes are the same as the previous version which used looping. Going forward, `np.dot` will be used for these operations. The prediction is now a single statement. Most routines will implement it directly rather than calling a separate predict routine.

# %% [markdown]
# <a name="toc_15456_4"></a>
# # 4 Compute Cost With Multiple Variables
# The equation for the cost function with multiple variables $J(\mathbf{w},b)$ is:
# $$J(\mathbf{w},b) = \frac{1}{2m} \sum\limits_{i = 0}^{m-1} (f_{\mathbf{w},b}(\mathbf{x}^{(i)}) - y^{(i)})^2 \tag{3}$$
# where:
# $$ f_{\mathbf{w},b}(\mathbf{x}^{(i)}) = \mathbf{w} \cdot \mathbf{x}^{(i)} + b  \tag{4} $$
#
#
# In contrast to previous labs, $\mathbf{w}$ and $\mathbf{x}^{(i)}$ are vectors rather than scalars supporting multiple features.

# %% [markdown]
# Below is an implementation of equations (3) and (4). Note that this uses a *standard pattern for this course* where a for loop over all `m` examples is used.

# %%
def compute_cost(X, y, w, b):
    """
    compute cost
    Args:
      X (ndarray (m,n)): Data, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters
      b (scalar)       : model parameter

    Returns:
      cost (scalar): cost
    """
    m = X.shape[0]
    cost = 0.0
    for i in range(m):
        f_wb_i = np.dot(X[i], w) + b           #(n,)(n,) = scalar (see np.dot)
        cost = cost + (f_wb_i - y[i])**2       #scalar
        print("target value",y[i],"predicted value",f_wb_i,"cost at ",(f_wb_i - y[i])**2)
    cost = cost / (2 * m)                      #scalar
    return cost

# %%
# Compute and display cost using our pre-chosen optimal parameters.
cost = compute_cost(X_train, y_train, w_init, b_init)
print(f'Cost at optimal w : {cost}')
# Out:
# target value 460 predicted value 459.9999976194083 cost at  5.667216819864136e-12
# target value 232 predicted value 231.9999983694081 cost at  2.6588299318664548e-12
# target value 178 predicted value 177.99999898940814 cost at  1.0212959056493869e-12
# Cost at optimal w : 1.5578904428966628e-12

# %% [markdown]
# **Expected Result**: Cost at optimal w : 1.5578904045996674e-12

# %% [markdown]
# <a name="toc_15456_5"></a>
# # 5 Gradient Descent With Multiple Variables
# Gradient descent for multiple variables:
#
# $$\begin{align*} \text{repeat}&\text{ until convergence:} \; \lbrace \newline\;
# & w_j = w_j -  \alpha \frac{\partial J(\mathbf{w},b)}{\partial w_j} \tag{5}  \; & \text{for j = 0..n-1}\newline
# &b\ \ = b -  \alpha \frac{\partial J(\mathbf{w},b)}{\partial b}  \newline \rbrace
# \end{align*}$$
#
# where, n is the number of features, parameters $w_j$,  $b$, are updated simultaneously and where
#
# $$
# \begin{align}
# \frac{\partial J(\mathbf{w},b)}{\partial w_j}  &= \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{\mathbf{w},b}(\mathbf{x}^{(i)}) - y^{(i)})x_{j}^{(i)} \tag{6}  \\
# \frac{\partial J(\mathbf{w},b)}{\partial b}  &= \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{\mathbf{w},b}(\mathbf{x}^{(i)}) - y^{(i)}) \tag{7}
# \end{align}
# $$
# * m is the number of training examples in the data set
#
#
# *  $f_{\mathbf{w},b}(\mathbf{x}^{(i)})$ is the model's prediction, while $y^{(i)}$ is the target value

# %% [markdown]
# <a name="toc_15456_5.1"></a>
# ## 5.1 Compute Gradient with Multiple Variables
# An implementation for calculating the equations (6) and (7) is below. There are many ways to implement this. In this version, there is an
# - outer loop over all m examples.
#     - $\frac{\partial J(\mathbf{w},b)}{\partial b}$ for the example can be computed directly and accumulated
#     - in a second loop over all n features:
#         - $\frac{\partial J(\mathbf{w},b)}{\partial w_j}$ is computed for each $w_j$.

# %%
def compute_gradient(X, y, w, b):
    """
    Computes the gradient for linear regression
    Args:
      X (ndarray (m,n)): Data, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters
      b (scalar)       : model parameter

    Returns:
      dj_dw (ndarray (n,)): The gradient of the cost w.r.t. the parameters w.
      dj_db (scalar):       The gradient of the cost w.r.t. the parameter b.
    """
    m,n = X.shape           #(number of examples, number of features)
    dj_dw = np.zeros((n,))
    dj_db = 0.

    for i in range(m):
        err = (np.dot(X[i], w) + b) - y[i]
        for j in range(n):
            dj_dw[j] = dj_dw[j] + err * X[i, j]
        dj_db = dj_db + err
    dj_dw = dj_dw / m
    dj_db = dj_db / m

    return dj_db, dj_dw

# %%
#Compute and display gradient
tmp_dj_db, tmp_dj_dw = compute_gradient(X_train, y_train, w_init, b_init)
print(f'dj_db at initial w,b: {tmp_dj_db}')
print(f'dj_dw at initial w,b: \n {tmp_dj_dw}')
# Out:
# dj_db at initial w,b: -1.6739251501955248e-06
# dj_dw at initial w,b:
#  [-2.73e-03 -6.27e-06 -2.22e-06 -6.92e-05]

# %% [markdown]
# **Expected Result**:
# dj_db at initial w,b: -1.6739251122999121e-06
# dj_dw at initial w,b:
#  [-2.73e-03 -6.27e-06 -2.22e-06 -6.92e-05]

# %% [markdown]
# <a name="toc_15456_5.2"></a>
# ## 5.2 Gradient Descent With Multiple Variables
# The routine below implements equation (5) above.

# %%
def gradient_descent(X, y, w_in, b_in, cost_function, gradient_function, alpha, num_iters):
    """
    Performs batch gradient descent to learn w and b. Updates w and b by taking
    num_iters gradient steps with learning rate alpha

    Args:
      X (ndarray (m,n))   : Data, m examples with n features
      y (ndarray (m,))    : target values
      w_in (ndarray (n,)) : initial model parameters
      b_in (scalar)       : initial model parameter
      cost_function       : function to compute cost
      gradient_function   : function to compute the gradient
      alpha (float)       : Learning rate
      num_iters (int)     : number of iterations to run gradient descent

    Returns:
      w (ndarray (n,)) : Updated values of parameters
      b (scalar)       : Updated value of parameter
      """

    # An array to store cost J and w's at each iteration primarily for graphing later
    J_history = []
    w = copy.deepcopy(w_in)  #avoid modifying global w within function
    b = b_in

    for i in range(num_iters):

        # Calculate the gradient and update the parameters
        dj_db,dj_dw = gradient_function(X, y, w, b)   ##None

        # Update Parameters using w, b, alpha and gradient
        w = w - alpha * dj_dw               ##None
        b = b - alpha * dj_db               ##None

        # Save cost J at each iteration
        if i<100000:      # prevent resource exhaustion
            J_history.append( cost_function(X, y, w, b))

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(num_iters / 10) == 0:
            print(f"Iteration {i:4d}: Cost {J_history[-1]:8.2f}   ")

    return w, b, J_history #return final w,b and J history for graphing

# %% [markdown]
# In the next cell you will test the implementation.

# %%
# initialize parameters
initial_w = np.zeros_like(w_init)
initial_b = 0.
# some gradient descent settings
iterations = 1000
alpha = 5.0e-7
# run gradient descent
w_final, b_final, J_hist = gradient_descent(X_train, y_train, initial_w, initial_b,
                                                    compute_cost, compute_gradient,
                                                    alpha, iterations)
print(f"b,w found by gradient descent: {b_final:0.2f},{w_final} ")
m,_ = X_train.shape
for i in range(m):
    val=np.dot(X_train[i], w_final) + b_final
    print(f"prediction: {np.dot(X_train[i], w_final) + b_final:0.2f}, target value: {y_train[i]}, cost {val-y_train[i]}",)
# Out:
# target value 460 predicted value 508.0428356666666 cost at  2308.11405889433
# target value 232 predicted value 341.9734763333332 cost at  12094.165496838203
# target value 178 predicted value 205.829807 cost at  774.4981576572484
# Iteration    0: Cost  2529.46
# target value 460 predicted value 409.61826419025846 cost at  2538.3193032025933
# target value 232 predicted value 275.7211279491076 cost at  1911.5370291422375
# target value 178 predicted value 165.95235435336173 cost at  145.14576562696212
# target value 460 predicted value 428.6872001143263 cost at  980.4914366802476
# target value 232 predicted value 288.55610299827777 cost at  3198.592786351803
# target value 178 predicted value 173.6768130859033 cost at  18.689945094217027
# target value 460 predicted value 424.9936196328413 cost at  1225.446666410196
# target value 232 predicted value 286.06915488340104 cost at  2923.4735098052106
# target value 178 predicted value 172.1791513369225 cost at  33.8822791584511
# target value 460 predicted value 425.7099181316527 cost at  1175.8097145379584
# target value 232 predicted value 286.5505880563804 cost at  2975.7666572969097
# target value 178 predicted value 172.46813022224904 cost at  30.601583237994408
# target value 460 predicted value 425.5718720076035 cost at  1185.2959970608372
# target value 232 predicted value 286.45694412727835 cost at  2965.5587636815158
# target value 178 predicted value 172.41097567891867 cost at  31.23719286163857
# target value 460 predicted value 425.59934166499625 cost at  1183.4052938816633
# target value 232 predicted value 286.4747123447689 cost at  2967.4942850453144
# target value 178 predicted value 172.4208790874839 cost at  31.126590156474357
# target value 460 predicted value 425.594745214712 cost at  1183.7215568405813
# target value 232 predicted value 286.4708962300767 cost at  2967.0785361077815
# target value 178 predicted value 172.41779112629666 cost at  31.161055909652276
# target value 460 predicted value 425.59636103558097 cost at  1183.6103739940913
# target value 232 predicted value 286.471261756085 cost at  2967.118357299931
# target value 178 predicted value 172.41722009053632 cost at  31.167431517511314
# target value 460 predicted value 425.5967732946435 cost at  1183.582007740153
# target value 232 predicted value 286.47081717139696 cost at  2967.069923319754
# target value 178 predicted value 172.41616149228665 cost at  31.179252480222477
# target value 460 predicted value 425.5974186927274 cost at  1183.537600603503
# target value 232 predicted value 286.4705295492179 cost at  2967.0385893722173
# target value 178 predicted value 172.41519740375432 cost at  31.19002003903249
# target value 460 predicted value 425.59801889167863 cost at  1183.4963041773
# target value 232 predicted value 286.47021153434616 cost at  2967.0039445964176
# target value 178 predicted value 172.41421505761534 cost at  31.200993422571234
# target value 460 predicted value 425.5986278151317 cost at  1183.4544082018308
# target value 232 predicted value 286.46989942390036 cost at  2966.9699432498205
# target value 178 predicted value 172.41323630076027 cost at  31.211928631142737
# target value 460 predicted value 425.59923501623365 cost at  1183.4126314683251
# target value 232 predicted value 286.4695861858849 cost at  2966.935819261544
# target value 178 predicted value 172.4122569006958 cost at  31.22287294382161
# target value 460 predicted value 425.5998425188985 cost at  1183.3708347245818
# target value 232 predicted value 286.44864278911746 cost at  2964.6547015769124
# target value 178 predicted value 172.34674401376847 cost at  31.959303245862607
# target value 460 predicted value 425.6404803949245 cost at  1180.576587491567
# target value 232 predicted value 286.4483306645233 cost at  2964.620712153271
# target value 178 predicted value 172.3457676917318 cost at  31.970342995864005
# target value 460 predicted value 425.64108601768555 cost at  1180.5349700440834
# target value 232 predicted value 286.44801855355814 cost at  2964.5867244086116
# target value 178 predicted value 172.34479141325383 cost at  31.98138415960761
# target value 460 predicted value 425.6416916136262 cost at  1180.4933551731626
# target value 232 predicted value 286.4477064562218 cost at  2964.5527383428966
# target value 178 predicted value 172.3438151783329 cost at  31.992426736857247
# target value 460 predicted value 425.64229718274737 cost at  1180.4517428786494
# target value 232 predicted value 286.44739437251326 cost at  2964.5187539559884
# target value 178 predicted value 172.34283898696677 cost at  32.00347072738318
# target value 460 predicted value 425.6429027250505 cost at  1180.410133160344
# target value 232 predicted value 286.4470823024321 cost at  2964.4847712478127
# target value 178 predicted value 172.3418628391537 cost at  32.01451613094993
# target value 460 predicted value 425.6435082405366 cost at  1180.3685260180753
# target value 232 predicted value 286.44677024597763 cost at  2964.450790218275
# target value 178 predicted value 172.3408867348917 cost at  32.025562947324595
# target value 460 predicted value 425.64411372920705 cost at  1180.3269214516595
# target value 232 predicted value 286.4464582031493 cost at  2964.4168108672825
# target value 178 predicted value 172.3399106741789 cost at  32.03661117627401
# target value 460 predicted value 425.64471919106285 cost at  1180.2853194609254
# target value 232 predicted value 286.44614617394654 cost at  2964.382833194754
# target value 178 predicted value 172.33893465701325 cost at  32.047660817565635
# target value 460 predicted value 425.6453246261053 cost at  1180.2437200456854
# target value 232 predicted value 286.4458341583687 cost at  2964.348857200589
# target value 178 predicted value 172.3379586833929 cost at  32.05871187096572
# target value 460 predicted value 425.64593003433566 cost at  1180.2021232057605
# target value 232 predicted value 286.4455221564152 cost at  2964.314882884701
# target value 178 predicted value 172.33698275331588 cost at  32.069764336241796
# target value 460 predicted value 425.646535415755 cost at  1180.1605289409747
# target value 232 predicted value 286.4452101680854 cost at  2964.280910246989
# target value 178 predicted value 172.33600686678022 cost at  32.080818213160775
# target value 460 predicted value 425.64714077036444 cost at  1180.1189372511567
# target value 232 predicted value 286.44489819337866 cost at  2964.2469392873672
# target value 178 predicted value 172.335031023784 cost at  32.09187350148962
# target value 460 predicted value 425.64774609816544 cost at  1180.0773481361077
# target value 232 predicted value 286.44458623229457 cost at  2964.2129700057594
# target value 178 predicted value 172.3340552243254 cost at  32.10293020099433
# target value 460 predicted value 425.64835139915886 cost at  1180.0357615956714
# target value 232 predicted value 286.44427428483215 cost at  2964.179002402035
# target value 178 predicted value 172.33307946840227 cost at  32.11398831144384
# target value 460 predicted value 425.64895667334616 cost at  1179.9941776296491
# target value 232 predicted value 286.44396235099117 cost at  2964.145036476144
# target value 178 predicted value 172.33210375601286 cost at  32.12504783260358
# target value 460 predicted value 425.6495619207285 cost at  1179.9525962378655
# target value 232 predicted value 286.4436504307709 cost at  2964.1110722279805
# target value 460 predicted value 425.6598470262133 cost at  1179.2461062630716
# target value 232 predicted value 286.43834987040304 cost at  2963.5339366124113
# target value 178 predicted value 172.31454837505075 cost at  32.32436017963809
# target value 460 predicted value 425.66045179130896 cost at  1179.204571177016
# target value 232 predicted value 286.4380381952515 cost at  2963.500002547664
# target value 178 predicted value 172.3135734894329 cost at  32.33544646008019
# target value 460 predicted value 425.66105652962216 cost at  1179.163038661805
# target value 232 predicted value 286.4377265337091 cost at  2963.466070158897
# target value 178 predicted value 172.3125986473101 cost at  32.346534146578946
# target value 460 predicted value 425.6616612411542 cost at  1179.1215087172513
# target value 232 predicted value 286.4374148857753 cost at  2963.43213944603
# target value 178 predicted value 172.31162384868026 cost at  32.35762323890322
# target value 460 predicted value 425.6622659259062 cost at  1179.0799813431836
# target value 232 predicted value 286.43710325144946 cost at  2963.398210408969
# target value 178 predicted value 172.31064909354149 cost at  32.368713736820325
# target value 460 predicted value 425.6628705838794 cost at  1179.038456539415
# target value 232 predicted value 286.436791630731 cost at  2963.364283047627
# target value 178 predicted value 172.30967438189188 cost at  32.379805640097544
# target value 460 predicted value 425.66347521507504 cost at  1178.9969343057662
# target value 232 predicted value 286.43648002361937 cost at  2963.3303573619105
# target value 178 predicted value 172.30869971372954 cost at  32.39089894850224
# target value 460 predicted value 425.66407981949425 cost at  1178.9554146420621
# target value 232 predicted value 286.4361684301138 cost at  2963.2964333517193
# target value 178 predicted value 172.30772508905238 cost at  32.4019936618037
# target value 460 predicted value 425.6646843971381 cost at  1178.9138975481317
# target value 232 predicted value 286.4358568502137 cost at  2963.2625110169606
# target value 178 predicted value 172.30675050785865 cost at  32.413089779767716
# target value 460 predicted value 425.66528894800797 cost at  1178.8723830237836
# target value 232 predicted value 286.43554528391877 cost at  2963.228590357571
# target value 178 predicted value 172.3057759701463 cost at  32.42418730216331
# target value 460 predicted value 425.665893472105 cost at  1178.8308710688432
# target value 232 predicted value 286.43523373122804 cost at  2963.194671373427
# target value 178 predicted value 172.3048014759134 cost at  32.43528622875826
# target value 460 predicted value 425.66649796943045 cost at  1178.7893616831232
# target value 232 predicted value 286.43492219214113 cost at  2963.160754064459
# target value 178 predicted value 172.3038270251581 cost at  32.44638655931906
# target value 460 predicted value 425.6671024399852 cost at  1178.7478548664722
# target value 232 predicted value 286.43461066665714 cost at  2963.1268384305426
# target value 178 predicted value 172.30285261787836 cost at  32.45748829361548
# target value 460 predicted value 425.66770688377085 cost at  1178.7063506186757
# target value 232 predicted value 286.43429915477594 cost at  2963.092924471641
# target value 178 predicted value 172.3018782540724 cost at  32.468591431413095
# target value 460 predicted value 425.66831130078816 cost at  1178.6648489395898
# target value 232 predicted value 286.43398765649647 cost at  2963.05901218761
# target value 178 predicted value 172.30090393373803 cost at  32.479695972482695
# target value 460 predicted value 425.6689156910389 cost at  1178.6233498289967
# target value 232 predicted value 286.43367617181843 cost at  2963.025101578394
# target value 178 predicted value 172.29992965687362 cost at  32.490801916588936
# target value 460 predicted value 425.6695200545236 cost at  1178.581853286756
# target value 232 predicted value 286.4333647007411 cost at  2962.9911926438867
# target value 178 predicted value 172.298955423477 cost at  32.50190926350235
# target value 460 predicted value 425.670124391244 cost at  1178.5403593126618
# target value 232 predicted value 286.4330532432638 cost at  2962.9572853839945
# target value 178 predicted value 172.2979812335464 cost at  32.51301801298893
# target value 460 predicted value 425.67072870120097 cost at  1178.4988679065468
# target value 232 predicted value 286.43274179938606 cost at  2962.923379798631
# target value 178 predicted value 172.29700708707975 cost at  32.52412816481861
# target value 460 predicted value 425.6713329843958 cost at  1178.4573790682316
# target value 232 predicted value 286.4324303691072 cost at  2962.889475887702
# target value 178 predicted value 172.29603298407523 cost at  32.53523971875778
# target value 460 predicted value 425.67193724082966 cost at  1178.4158927975373
# target value 232 predicted value 286.4321189524267 cost at  2962.855573651132
# target value 178 predicted value 172.29505892453085 cost at  32.54635267457511
# target value 460 predicted value 425.67254147050375 cost at  1178.3744090942853
# target value 232 predicted value 286.43180754934383 cost at  2962.821673088804
# target value 178 predicted value 172.29408490844463 cost at  32.55746703203931
# target value 460 predicted value 425.6731456734193 cost at  1178.3329279582922
# target value 232 predicted value 286.431496159858 cost at  2962.7877742006362
# target value 178 predicted value 172.29311093581472 cost at  32.568582790917496
# target value 460 predicted value 425.67374984957735 cost at  1178.2914493893911
# target value 232 predicted value 286.43118478396866 cost at  2962.7538769865414
# target value 178 predicted value 172.29213700663917 cost at  32.5796999509781
# target value 460 predicted value 425.67435399897937 cost at  1178.2499733873835
# target value 232 predicted value 286.4308734216753 cost at  2962.719981446439
# target value 178 predicted value 172.29116312091608 cost at  32.590818511988616
# target value 460 predicted value 425.6749581216264 cost at  1178.208499952102
# target value 232 predicted value 286.43056207297724 cost at  2962.686087580228
# target value 178 predicted value 172.29018927864345 cost at  32.60193847371817
# target value 460 predicted value 425.6755622175193 cost at  1178.1670290833877
# target value 232 predicted value 286.43025073787356 cost at  2962.6521953877855
# target value 178 predicted value 172.28921547981932 cost at  32.61305983593529
# target value 460 predicted value 425.6761662866599 cost at  1178.125560781022
# target value 232 predicted value 286.4299394163642 cost at  2962.6183048690796
# target value 178 predicted value 172.28824172444195 cost at  32.624182598405916
# target value 460 predicted value 425.676770329049 cost at  1178.0840950448496
# target value 232 predicted value 286.4296281084482 cost at  2962.5844160239726
# target value 178 predicted value 172.28726801250917 cost at  32.63530676090089
# target value 460 predicted value 425.6773743446878 cost at  1178.0426318746959
# target value 232 predicted value 286.42931681412506 cost at  2962.550528852397
# target value 178 predicted value 172.28629434401913 cost at  32.64643232318783
# target value 460 predicted value 425.67797833357747 cost at  1178.0011712703774
# target value 232 predicted value 286.42900553339416 cost at  2962.516643354252
# target value 178 predicted value 172.28532071896993 cost at  32.65755928503439
# target value 460 predicted value 425.6785822957194 cost at  1177.9597132317042
# target value 232 predicted value 286.42869426625504 cost at  2962.4827595294637
# target value 178 predicted value 172.28434713735967 cost at  32.668687646208554
# target value 460 predicted value 425.6791862311145 cost at  1177.9182577585204
# target value 232 predicted value 286.4283830127068 cost at  2962.4488773779076
# target value 178 predicted value 172.28337359918632 cost at  32.67981740647998
# target value 460 predicted value 425.6797901397642 cost at  1177.876804850628
# target value 232 predicted value 286.428071772749 cost at  2962.4149968995143
# target value 178 predicted value 172.2824001044481 cost at  32.69094856561509
# target value 460 predicted value 425.6803940216696 cost at  1177.835354507852
# target value 232 predicted value 286.42776054638114 cost at  2962.381118094203
# target value 178 predicted value 172.28142665314292 cost at  32.70208112338424
# target value 460 predicted value 425.6809978768319 cost at  1177.793906730017
# target value 232 predicted value 286.4274493336024 cost at  2962.347240961856
# target value 178 predicted value 172.2804532452689 cost at  32.7132150795552
# target value 460 predicted value 425.6816017052522 cost at  1177.7524615169484
# target value 232 predicted value 286.42713813441225 cost at  2962.3133655023917
# target value 178 predicted value 172.27947988082408 cost at  32.72435043389643
# target value 460 predicted value 425.6822055069319 cost at  1177.7110188684558
# target value 232 predicted value 286.4268269488103 cost at  2962.2794917157416
# target value 178 predicted value 172.2785065598067 cost at  32.73548718617512
# target value 460 predicted value 425.6828092818718 cost at  1177.6695787843835
# target value 232 predicted value 286.4265157767956 cost at  2962.2456196017815
# target value 178 predicted value 172.2775332822146 cost at  32.746625336161706
# target value 460 predicted value 425.6834130300736 cost at  1177.6281412645217
# target value 232 predicted value 286.4262046183678 cost at  2962.2117491604427
# target value 178 predicted value 172.27656004804595 cost at  32.757764883623764
# target value 460 predicted value 425.68401675153814 cost at  1177.586706308715
# target value 232 predicted value 286.4258934735261 cost at  2962.1778803916127
# target value 178 predicted value 172.27558685729883 cost at  32.76890582832985
# target value 460 predicted value 425.68462044626665 cost at  1177.5452739167808
# target value 232 predicted value 286.42558234227016 cost at  2962.1440132952293
# target value 178 predicted value 172.27461370997133 cost at  32.78004817004822
# target value 460 predicted value 425.6852241142604 cost at  1177.5038440885364
# target value 232 predicted value 286.4252712245991 cost at  2962.110147871175
# target value 178 predicted value 172.27364060606138 cost at  32.79119190854911
# target value 460 predicted value 425.68582775552056 cost at  1177.4624168238029
# target value 232 predicted value 286.42496012051254 cost at  2962.07628411938
# target value 178 predicted value 172.2726675455673 cost at  32.802337043598236
# target value 460 predicted value 425.68643137004835 cost at  1177.4209921224017
# target value 232 predicted value 286.42464903000973 cost at  2962.0424220397394
# target value 178 predicted value 172.27169452848688 cost at  32.8134835749672
# target value 460 predicted value 425.6870349578449 cost at  1177.3795699841578
# target value 232 predicted value 286.42433795309 cost at  2962.008561632153
# target value 178 predicted value 172.27072155481838 cost at  32.824631502422726
# target value 460 predicted value 425.6876385189112 cost at  1177.3381504089045
# target value 232 predicted value 286.4240268897529 cost at  2961.974702896546
# target value 178 predicted value 172.26974862455975 cost at  32.835780825734844
# target value 460 predicted value 425.6882420532489 cost at  1177.2967333964355
# target value 232 predicted value 286.42371583999784 cost at  2961.9408458328317
# target value 178 predicted value 172.2687757377092 cost at  32.84693154467066
# target value 460 predicted value 425.6888455608591 cost at  1177.2553189465798
# target value 232 predicted value 286.42340480382416 cost at  2961.9069904409102
# target value 178 predicted value 172.26780289426478 cost at  32.858083658999284
# target value 460 predicted value 425.6894490417423 cost at  1177.213907059198
# target value 232 predicted value 286.4230937812311 cost at  2961.8731367206756
# target value 178 predicted value 172.26683009422436 cost at  32.86923716849146
# target value 460 predicted value 425.6900524959007 cost at  1177.1724977340486
# target value 232 predicted value 286.4227827722183 cost at  2961.8392846720594
# target value 178 predicted value 172.26585733758623 cost at  32.88039207291372
# target value 460 predicted value 425.69065592333476 cost at  1177.1310909710041
# target value 232 predicted value 286.42247177678513 cost at  2961.805434294974
# target value 178 predicted value 172.26488462434838 cost at  32.89154837203559
# target value 460 predicted value 425.69125932404603 cost at  1177.0896867698584
# target value 232 predicted value 286.42216079493085 cost at  2961.771585589308
# target value 178 predicted value 172.26391195450884 cost at  32.902706065626575
# target value 460 predicted value 425.6918626980355 cost at  1177.0482851304484
# target value 232 predicted value 286.4218498266549 cost at  2961.7377385549803
# target value 178 predicted value 172.26293932806576 cost at  32.91386515345461
# target value 460 predicted value 425.69246604530446 cost at  1177.0068860525876
# target value 232 predicted value 286.4215388719567 cost at  2961.703893191897
# target value 178 predicted value 172.2619667450171 cost at  32.92502563528959
# target value 460 predicted value 425.6930693658541 cost at  1176.9654895360975
# target value 232 predicted value 286.4212279308357 cost at  2961.6700494999714
# target value 178 predicted value 172.26099420536113 cost at  32.936187510898534
# target value 460 predicted value 425.6936726596857 cost at  1176.9240955807952
# target value 232 predicted value 286.4209170032913 cost at  2961.6362074791227
# target value 178 predicted value 172.26002170909572 cost at  32.94735078005237
# target value 460 predicted value 425.6942759268002 cost at  1176.882704186522
# target value 232 predicted value 286.42060608932275 cost at  2961.602367129232
# target value 178 predicted value 172.25904925621896 cost at  32.958515442520095
# target value 460 predicted value 425.6948791671988 cost at  1176.8413153530914
# target value 232 predicted value 286.42029518892946 cost at  2961.5685284502188
# target value 178 predicted value 172.258076846729 cost at  32.969681498069455
# target value 460 predicted value 425.695482380883 cost at  1176.799929080309
# target value 232 predicted value 286.419984302111 cost at  2961.534691442008
# target value 178 predicted value 172.25710448062398 cost at  32.98084894646917
# target value 460 predicted value 425.6960855678538 cost at  1176.7585453680083
# target value 232 predicted value 286.41967342886676 cost at  2961.5008561045065
# target value 178 predicted value 172.25613215790182 cost at  32.99201778748964
# target value 460 predicted value 425.69668872811224 cost at  1176.7171642160222
# target value 232 predicted value 286.41936256919587 cost at  2961.4670224375964
# target value 178 predicted value 172.2551598785606 cost at  33.00318802089997
# target value 460 predicted value 425.6972918616598 cost at  1176.6757856241525
# target value 232 predicted value 286.41905172309816 cost at  2961.4331904412334
# target value 178 predicted value 172.25418764259854 cost at  33.01435964646735
# target value 460 predicted value 425.6978949684974 cost at  1176.6344095922364
# target value 232 predicted value 286.41874089057245 cost at  2961.399360115262
# target value 178 predicted value 172.25321545001344 cost at  33.0255326639642
# target value 460 predicted value 425.6984980486265 cost at  1176.5930361200797
# target value 232 predicted value 286.4184300716186 cost at  2961.3655314596454
# target value 178 predicted value 172.2522433008037 cost at  33.0367070731558
# target value 460 predicted value 425.6991011020481 cost at  1176.5516652075196
# target value 232 predicted value 286.4181192662359 cost at  2961.331704474277
# target value 178 predicted value 172.2512711949672 cost at  33.04788287381398
# target value 460 predicted value 425.69970412876324 cost at  1176.5102968543813
# target value 232 predicted value 286.4178084744236 cost at  2961.2978791590513
# target value 178 predicted value 172.25029913250197 cost at  33.059060065707655
# target value 460 predicted value 425.7003071287735 cost at  1176.4689310604667
# target value 232 predicted value 286.4174976961813 cost at  2961.264055513894
# target value 178 predicted value 172.2493271134062 cost at  33.07023864860512
# target value 460 predicted value 425.7009101020798 cost at  1176.4275678256133
# target value 232 predicted value 286.4171869315083 cost at  2961.2302335387176
# target value 178 predicted value 172.24835513767795 cost at  33.08141862227566
# target value 460 predicted value 425.7015130486834 cost at  1176.3862071496344
# target value 232 predicted value 286.41687618040385 cost at  2961.1964132334037
# target value 178 predicted value 172.24738320531517 cost at  33.09259998648992
# target value 460 predicted value 425.7021159685855 cost at  1176.3448490323594
# target value 232 predicted value 286.4165654428677 cost at  2961.1625945979026
# target value 178 predicted value 172.24641131631606 cost at  33.10378274101594
# target value 460 predicted value 425.7027188617871 cost at  1176.303493473614
# target value 232 predicted value 286.4162547188989 cost at  2961.1287776320896
# target value 178 predicted value 172.2454394706787 cost at  33.114966885622756
# target value 460 predicted value 425.7033217282898 cost at  1176.2621404732
# target value 232 predicted value 286.41594400849715 cost at  2961.094962335897
# target value 178 predicted value 172.24446766840111 cost at  33.1261524200801
# target value 460 predicted value 425.7039245680943 cost at  1176.220790030966
# target value 232 predicted value 286.4156333116615 cost at  2961.0611487092056
# target value 178 predicted value 172.24349590948123 cost at  33.13733934415938
# target value 460 predicted value 425.7045273812021 cost at  1176.1794421467146
# target value 232 predicted value 286.41532262839166 cost at  2961.027336751954
# target value 178 predicted value 172.2425241939174 cost at  33.14852765762644
# target value 460 predicted value 425.70513016761436 cost at  1176.138096820275
# target value 232 predicted value 286.41501195868676 cost at  2960.9935264640235
# target value 178 predicted value 172.24155252170752 cost at  33.15971736025304
# target value 460 predicted value 425.7057329273323 cost at  1176.0967540514605
# target value 232 predicted value 286.4147013025466 cost at  2960.959717845364
# target value 178 predicted value 172.24058089284972 cost at  33.17090845180772
# target value 460 predicted value 425.7063356603568 cost at  1176.0554138401167
# target value 232 predicted value 286.41439065997 cost at  2960.925910895833
# target value 178 predicted value 172.239609307342 cost at  33.18210093206099
# target value 460 predicted value 425.7069383666894 cost at  1176.0140761860375
# target value 232 predicted value 286.4140800309568 cost at  2960.8921056153745
# target value 178 predicted value 172.23863776518252 cost at  33.1932948007811
# target value 460 predicted value 425.70754104633113 cost at  1175.9727410890644
# target value 232 predicted value 286.41376941550624 cost at  2960.858302003882
# target value 178 predicted value 172.2376662663693 cost at  33.20449005773829
# target value 460 predicted value 425.7081436992833 cost at  1175.9314085490028
# target value 232 predicted value 286.4134588136178 cost at  2960.8245000612815
# target value 178 predicted value 172.23669481090047 cost at  33.215686702701525
# target value 460 predicted value 425.7087463255469 cost at  1175.8900785656945
# target value 232 predicted value 286.41314822529074 cost at  2960.7906997874607
# target value 178 predicted value 172.23572339877404 cost at  33.22688473544109
# target value 460 predicted value 425.7093489251232 cost at  1175.848751138949
# target value 232 predicted value 286.4128376505247 cost at  2960.7569011823575
# target value 178 predicted value 172.23475202998816 cost at  33.238084155725666
# target value 460 predicted value 425.70995149801354 cost at  1175.807426268584
# target value 232 predicted value 286.4125270893188 cost at  2960.723104245854
# target value 178 predicted value 172.23378070454075 cost at  33.24928496332658
# target value 460 predicted value 425.7105540442188 cost at  1175.766103954441
# target value 232 predicted value 286.41221654167254 cost at  2960.6893089778623
# target value 178 predicted value 172.23280942243 cost at  33.26048715801225
# target value 460 predicted value 425.7111565637404 cost at  1175.724784196322
# target value 232 predicted value 286.4119060075853 cost at  2960.655515378296
# target value 178 predicted value 172.23183818365396 cost at  33.27169073955241
# target value 460 predicted value 425.71175905657947 cost at  1175.6834669940602
# target value 232 predicted value 286.4115954870566 cost at  2960.62172344708
# target value 178 predicted value 172.23086698821078 cost at  33.28289570771618
# target value 460 predicted value 425.7123615227373 cost at  1175.6421523474658
# target value 232 predicted value 286.41128498008567 cost at  2960.587933184096
# target value 178 predicted value 172.2298958360984 cost at  33.29410206227466
# Iteration  200: Cost   694.92
# target value 460 predicted value 425.7129639622148 cost at  1175.60084025638
# target value 232 predicted value 286.410974486672 cost at  2960.55414458927
# target value 178 predicted value 172.22892472731496 cost at  33.305309802996696
# ...
# target value 178 predicted value 171.52957185289324 cost at  41.866440406871405
# target value 460 predicted value 426.1474523999009 cost at  1145.9949790169762
# target value 232 predicted value 286.186990452379 cost at  2936.229934286214
# target value 178 predicted value 171.52863199149442 cost at  41.87860390150946
# target value 460 predicted value 426.14803557270375 cost at  1145.955495586931
# target value 232 predicted value 286.1866897491264 cost at  2936.1973459680803
# target value 178 predicted value 171.5276921720332 cost at  41.89076861996034
# target value 460 predicted value 426.14861871968446 cost at  1145.916014585297
# target value 232 predicted value 286.18638905899525 cost at  2936.1647592527997
# target value 178 predicted value 171.5267523945077 cost at  41.90293456201185
# target value 460 predicted value 426.14920184084406 cost at  1145.8765360119153
# target value 232 predicted value 286.1860883819848 cost at  2936.1321741402685
# target value 178 predicted value 171.52581265891592 cost at  41.91510172745329
# target value 460 predicted value 426.14978493618344 cost at  1145.8370598666338
# target value 232 predicted value 286.1857877180944 cost at  2936.099590630389
# target value 178 predicted value 171.52487296525607 cost at  41.927270116071774
# target value 460 predicted value 426.15036800570437 cost at  1145.7975861492428
# target value 232 predicted value 286.1854870673237 cost at  2936.067008723106
# target value 178 predicted value 171.52393331352644 cost at  41.93943972765261
# target value 460 predicted value 426.1509510494074 cost at  1145.7581148596132
# target value 232 predicted value 286.18518642967194 cost at  2936.0344284183047
# target value 178 predicted value 171.52299370372492 cost at  41.95161056198701
# target value 460 predicted value 426.15153406729394 cost at  1145.7186459975628
# target value 232 predicted value 286.18488580513855 cost at  2936.001849715905
# target value 178 predicted value 171.52205413584974 cost at  41.96378261886142
# target value 460 predicted value 426.1521170593651 cost at  1145.6791795629242
# target value 232 predicted value 286.1845851937231 cost at  2935.9692726158346
# target value 178 predicted value 171.52111460989912 cost at  41.97595589806269
# target value 460 predicted value 426.152700025622 cost at  1145.63971555553
# target value 232 predicted value 286.18428459542474 cost at  2935.936697117983
# target value 178 predicted value 171.52017512587105 cost at  41.98813039938028
# target value 460 predicted value 426.1532829660659 cost at  1145.6002539752055
# target value 232 predicted value 286.1839840102432 cost at  2935.90412322229
# target value 178 predicted value 171.5192356837638 cost at  42.00030612260033
# target value 460 predicted value 426.1538658806977 cost at  1145.5607948217987
# target value 232 predicted value 286.1836834381777 cost at  2935.8715509286517
# target value 178 predicted value 171.51829628357544 cost at  42.01248306751198
# target value 460 predicted value 426.1544487695189 cost at  1145.5213380951193
# target value 232 predicted value 286.18338287922774 cost at  2935.8389802369893
# target value 178 predicted value 171.5173569253041 cost at  42.024661233902535
# target value 460 predicted value 426.1550316325303 cost at  1145.481883795023
# target value 232 predicted value 286.1830823333925 cost at  2935.8064111471926
# target value 178 predicted value 171.5164176089479 cost at  42.03684062156081
# target value 460 predicted value 426.15561446973334 cost at  1145.4424319213235
# target value 232 predicted value 286.18278180067165 cost at  2935.773843659195
# target value 178 predicted value 171.51547833450502 cost at  42.0490212302738
# target value 460 predicted value 426.1561972811289 cost at  1145.4029824738652
# target value 232 predicted value 286.1824812810646 cost at  2935.741277772917
# target value 178 predicted value 171.51453910197358 cost at  42.06120305982962
# target value 460 predicted value 426.1567800667184 cost at  1145.3635354524693
# target value 232 predicted value 286.1821807745708 cost at  2935.7087134882677
# target value 178 predicted value 171.51359991135172 cost at  42.07338611001643
# target value 460 predicted value 426.1573628265028 cost at  1145.3240908569762
# target value 232 predicted value 286.1818802811894 cost at  2935.676150805143
# target value 178 predicted value 171.51266076263758 cost at  42.08557038062202
# target value 460 predicted value 426.15794556048337 cost at  1145.2846486872072
# target value 232 predicted value 286.1815798009202 cost at  2935.643589723483
# target value 178 predicted value 171.51172165582932 cost at  42.09775587143423
# target value 460 predicted value 426.158528268661 cost at  1145.2452089430185
# target value 232 predicted value 286.1812793337622 cost at  2935.6110302431644
# target value 178 predicted value 171.51078259092495 cost at  42.109942582242745
# target value 460 predicted value 426.15911095103706 cost at  1145.2057716242196
# target value 232 predicted value 286.1809788797151 cost at  2935.5784723641336
# target value 178 predicted value 171.50984356792276 cost at  42.1221305128336
# target value 460 predicted value 426.15969360761284 cost at  1145.1663367306394
# target value 232 predicted value 286.1806784387783 cost at  2935.545916086293
# target value 178 predicted value 171.50890458682088 cost at  42.13431966299507
# target value 460 predicted value 426.16027623838914 cost at  1145.1269042621304
# target value 232 predicted value 286.1803780109511 cost at  2935.5133614095507
# target value 178 predicted value 171.50796564761734 cost at  42.146510032516545
# target value 460 predicted value 426.16085884336735 cost at  1145.0874742185097
# target value 232 predicted value 286.18007759623305 cost at  2935.4808083338344
# target value 178 predicted value 171.5070267503103 cost at  42.15870162118599
# target value 460 predicted value 426.1614414225484 cost at  1145.0480465996218
# target value 232 predicted value 286.17977719462334 cost at  2935.4482568590274
# target value 178 predicted value 171.50608789489795 cost at  42.170894428791
# target value 460 predicted value 426.1620239759338 cost at  1145.0086214052806
# target value 232 predicted value 286.17947680612167 cost at  2935.415706985076
# target value 178 predicted value 171.50514908137848 cost at  42.18308845511884
# target value 460 predicted value 426.1626065035243 cost at  1144.9691986353378
# target value 232 predicted value 286.1791764307273 cost at  2935.383158711876
# target value 178 predicted value 171.50421030974988 cost at  42.19528369995975
# target value 460 predicted value 426.16318900532144 cost at  1144.9297782895997
# target value 232 predicted value 286.1788760684399 cost at  2935.350612039367
# target value 178 predicted value 171.50327158001042 cost at  42.20748016310031
# target value 460 predicted value 426.1637714813258 cost at  1144.8903603679416
# target value 232 predicted value 286.1785757192583 cost at  2935.3180669674025
# target value 178 predicted value 171.50233289215808 cost at  42.21967784433078
# target value 460 predicted value 426.16435393153927 cost at  1144.8509448701423
# target value 232 predicted value 286.17827538318244 cost at  2935.285523495952
# target value 178 predicted value 171.5013942461912 cost at  42.2318767434367
# target value 460 predicted value 426.1649363559623 cost at  1144.811531796081
# target value 232 predicted value 286.1779750602117 cost at  2935.252981624919
# target value 178 predicted value 171.50045564210774 cost at  42.244076860209134
# target value 460 predicted value 426.1655187545963 cost at  1144.7721211455753
# target value 232 predicted value 286.1776747503451 cost at  2935.22044135418
# target value 178 predicted value 171.4995170799059 cost at  42.25627819443512
# target value 460 predicted value 426.16610112744274 cost at  1144.7327129184312
# target value 232 predicted value 286.1773744535827 cost at  2935.1879026837123
# target value 178 predicted value 171.49857855958396 cost at  42.26848074590136
# target value 460 predicted value 426.16668347450235 cost at  1144.6933071145124
# target value 232 predicted value 286.17707416992323 cost at  2935.155365613363
# target value 178 predicted value 171.49764008113976 cost at  42.28068451440009
# target value 460 predicted value 426.1672657957763 cost at  1144.6539037336481
# target value 232 predicted value 286.17677389936654 cost at  2935.1228301430833
# target value 178 predicted value 171.49670164457171 cost at  42.29288949971624
# target value 460 predicted value 426.167848091266 cost at  1144.614502775652
# target value 232 predicted value 286.176473641912 cost at  2935.0902962727882
# target value 178 predicted value 171.49576324987783 cost at  42.30509570163987
# target value 460 predicted value 426.16843036097225 cost at  1144.575104240384
# target value 232 predicted value 286.17617339755884 cost at  2935.057764002362
# target value 178 predicted value 171.49482489705622 cost at  42.31730311995963
# target value 460 predicted value 426.1690126048967 cost at  1144.5357081276388
# target value 232 predicted value 286.17587316630664 cost at  2935.0252333317444
# target value 178 predicted value 171.49388658610516 cost at  42.32951175446234
# target value 460 predicted value 426.1695948230399 cost at  1144.4963144372878
# target value 232 predicted value 286.1755729481549 cost at  2934.9927042608556
# target value 178 predicted value 171.49294831702258 cost at  42.341721604939266
# target value 460 predicted value 426.17017701540334 cost at  1144.4569231691444
# target value 232 predicted value 286.1752727431028 cost at  2934.9601767895797
# target value 178 predicted value 171.4920100898068 cost at  42.35393267117653
# target value 460 predicted value 426.17075918198833 cost at  1144.4175343230268
# target value 232 predicted value 286.17497255115 cost at  2934.9276509178567
# target value 178 predicted value 171.49107190445594 cost at  42.36614495296288
# target value 460 predicted value 426.1713413227956 cost at  1144.3781478987949
# target value 232 predicted value 286.1746723722956 cost at  2934.89512664557
# target value 178 predicted value 171.490133760968 cost at  42.37835845008855
# target value 460 predicted value 426.17192343782636 cost at  1144.3387638962813
# target value 232 predicted value 286.17437220653926 cost at  2934.8626039726537
# target value 178 predicted value 171.4891956593412 cost at  42.390573162341575
# target value 460 predicted value 426.17250552708214 cost at  1144.2993823152885
# target value 232 predicted value 286.1740720538805 cost at  2934.830082899034
# target value 178 predicted value 171.48825759957376 cost at  42.40278908950893
# target value 460 predicted value 426.17308759056374 cost at  1144.2600031556728
# target value 232 predicted value 286.1737719143184 cost at  2934.7975634245954
# target value 178 predicted value 171.4873195816637 cost at  42.41500623138093
# target value 460 predicted value 426.1736696282723 cost at  1144.2206264172673
# target value 232 predicted value 286.17347178785263 cost at  2934.7650455492653
# target value 178 predicted value 171.48638160560924 cost at  42.42722458774568
# target value 460 predicted value 426.17425164020915 cost at  1144.1812520998933
# target value 232 predicted value 286.1731716744826 cost at  2934.7325292729643
# target value 178 predicted value 171.48544367140855 cost at  42.439444158390955
# target value 460 predicted value 426.17483362637546 cost at  1144.1418802033804
# target value 232 predicted value 286.1728715742077 cost at  2934.7000145956013
# target value 178 predicted value 171.48450577905962 cost at  42.451664943107524
# target value 460 predicted value 426.1754155867721 cost at  1144.1025107275805
# target value 232 predicted value 286.1725714870272 cost at  2934.667501517072
# target value 178 predicted value 171.48356792856066 cost at  42.46388694168321
# target value 460 predicted value 426.17599752140046 cost at  1144.0631436723077
# target value 232 predicted value 286.1722714129407 cost at  2934.634990037311
# target value 178 predicted value 171.48263011990986 cost at  42.47611015390621
# target value 460 predicted value 426.1765794302615 cost at  1144.0237790374106
# target value 232 predicted value 286.1719713519475 cost at  2934.60248015622
# target value 178 predicted value 171.48169235310527 cost at  42.48833457956626
# target value 460 predicted value 426.17716131335663 cost at  1143.9844168226991
# target value 232 predicted value 286.17167130404704 cost at  2934.5699718737133
# target value 178 predicted value 171.48075462814512 cost at  42.50056021845126
# target value 460 predicted value 426.17774317068677 cost at  1143.9450570280255
# target value 232 predicted value 286.1713712692389 cost at  2934.537465189719
# target value 178 predicted value 171.47981694502752 cost at  42.51278707035023
# target value 460 predicted value 426.17832500225325 cost at  1143.9056996532079
# target value 232 predicted value 286.17107124752226 cost at  2934.5049601041333
# target value 178 predicted value 171.4788793037506 cost at  42.52501513505223
# target value 460 predicted value 426.17890680805675 cost at  1143.86634469811
# target value 232 predicted value 286.1707712388965 cost at  2934.4724566168584
# target value 178 predicted value 171.47794170431243 cost at  42.53724441234707
# target value 460 predicted value 426.1794885880991 cost at  1143.8269921625188
# target value 232 predicted value 286.17047124336153 cost at  2934.4399547278585
# target value 178 predicted value 171.47700414671132 cost at  42.549474902021274
# target value 460 predicted value 426.18007034238104 cost at  1143.7876420462942
# target value 232 predicted value 286.1701712609162 cost at  2934.4074544369937
# target value 178 predicted value 171.4760666309453 cost at  42.561706603865446
# target value 460 predicted value 426.18065207090376 cost at  1143.748294349266
# target value 232 predicted value 286.1698712915601 cost at  2934.37495574419
# target value 178 predicted value 171.47512915701245 cost at  42.5739395176691
# target value 460 predicted value 426.1812337736684 cost at  1143.7089490712672
# target value 232 predicted value 286.16957133529286 cost at  2934.3424586493816
# target value 178 predicted value 171.47419172491098 cost at  42.58617364322033
# target value 460 predicted value 426.18181545067625 cost at  1143.6696062121193
# target value 232 predicted value 286.1692713921136 cost at  2934.3099631524583
# target value 178 predicted value 171.47325433463902 cost at  42.5984089803083
# target value 460 predicted value 426.1823971019282 cost at  1143.6302657716749
# target value 232 predicted value 286.168971462022 cost at  2934.277469253354
# target value 178 predicted value 171.47231698619473 cost at  42.61064552872189
# target value 460 predicted value 426.1829787274255 cost at  1143.5909277497558
# target value 232 predicted value 286.16867154501716 cost at  2934.244976951952
# target value 178 predicted value 171.47137967957627 cost at  42.622883288249604
# target value 460 predicted value 426.1835603271696 cost at  1143.5515921461797
# target value 232 predicted value 286.16837164109893 cost at  2934.2124862482106
# target value 178 predicted value 171.47044241478176 cost at  42.635122258681086
# target value 460 predicted value 426.1841419011611 cost at  1143.5122589608065
# target value 232 predicted value 286.1680717502663 cost at  2934.1799971419955
# target value 178 predicted value 171.46950519180928 cost at  42.647362439806
# target value 460 predicted value 426.18472344940153 cost at  1143.4729281934547
# target value 232 predicted value 286.16777187251887 cost at  2934.1475096332465
# target value 178 predicted value 171.46856801065707 cost at  42.6596038314122
# target value 460 predicted value 426.18530497189204 cost at  1143.4335998439494
# target value 232 predicted value 286.1674720078562 cost at  2934.115023721884
# target value 178 predicted value 171.46763087132317 cost at  42.671846433290135
# b,w found by gradient descent: -0.00,[ 0.2   0.   -0.01 -0.07]
# prediction: 426.19, target value: 460, cost -33.81469502810796
# prediction: 286.17, target value: 232, cost 54.16747200785619
# prediction: 171.47, target value: 178, cost -6.532369128676834

# %% [markdown]
# **Expected Result**:
# b,w found by gradient descent: -0.00,[ 0.2   0.   -0.01 -0.07]
# prediction: 426.19, target value: 460
# prediction: 286.17, target value: 232
# prediction: 171.47, target value: 178

# %%
# plot cost versus iteration
fig, (ax1, ax2) = plt.subplots(1, 2, constrained_layout=True, figsize=(12, 4))
ax1.plot(J_hist)
ax2.plot(100 + np.arange(len(J_hist[100:])), J_hist[100:])
ax1.set_title("Cost vs. iteration");  ax2.set_title("Cost vs. iteration (tail)")
ax1.set_ylabel('Cost')             ;  ax2.set_ylabel('Cost')
ax1.set_xlabel('iteration step')   ;  ax2.set_xlabel('iteration step')
plt.show()

# %% [markdown]
# *These results are not inspiring*! Cost is still declining and our predictions are not very accurate. The next lab will explore how to improve on this.

# %% [markdown]
# <a name="toc_15456_6"></a>
# # 6 Congratulations!
# In this lab you:
# - Redeveloped the routines for linear regression, now with multiple variables.
# - Utilized NumPy `np.dot` to vectorize the implementations

# %%
from sklearn import preprocessing
sx = preprocessing.MinMaxScaler()
sy = preprocessing.MinMaxScaler()

scaled_X = sx.fit_transform(X_train)
scaled_Y=sy.fit_transform(y_train.reshape(-1,1))

# %%
def predict(x,w,b):
  scaled=sx.transform([x])[0]
  val=scaled[0]*w[0]+scaled[1]*w[1]+scaled[2]*w[2]+b
  return sy.inverse_transform([[val]])[0][0]

# %%
print (X_train[2])
print (y_train[2])
predict(X_train[2],w_final,b_final)
# Out:
# [852   2   1  35]
# 178
# 177.36961507627703
